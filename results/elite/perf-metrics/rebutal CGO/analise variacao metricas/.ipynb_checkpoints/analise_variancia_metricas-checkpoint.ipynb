# %%
import pandas as pd
import os
import sys
import statistics
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

pula = 4

def juntar(files):
    df = list()
    for f in files:
        #print(f)
        path = os.path.join(directory, f)
        df.append(pd.read_csv(path))
    return df

def salvar(df,all_entries,i):
    nome = all_entries[0:4] + f'{i%pula:2d}' + '.csv'
    ds.to_csv('./' + nome)


directory_path = '.' # Current directory, or specify your path like '/path/to/your/directory'

# Get all entries in the directory
all_entries = sorted(os.listdir(directory_path))


# Iterate and print only the files
print(f"Files in '{directory_path}':")
i=0
while i < len(all_entries):
    full_path = os.path.join(directory_path, entry) # Construct full path
    if os.path.isfile(full_path):
        
        print(i, ' ', i+pula)
        df = juntar([all_entries[i],all_entries[i+4)])
        #df = seleciona_colunas(df,lista_colunas);
        salvar(df,all_entries(i),i)
        
        if (i+1)%pula == 0:
            i +=pula
    i+=1
# Out:
# Files in '.':
# 0   4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 33>()
#      35 if os.path.isfile(full_path):
#      37     print(i, ' ', i+pula)
# ---> 38     df = juntar([all_entries[i],all_entries(i+4)])
#      39     #df = seleciona_colunas(df,lista_colunas);
#      40     salvar(df,all_entries(i),i)
#
# TypeError: 'list' object is not callable
